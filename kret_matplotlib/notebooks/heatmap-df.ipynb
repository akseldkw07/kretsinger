# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from kret_notebook import *  # NOTE import first
from kret_matplotlib.mpl_nb_imports import *
from kret_np_pd.np_pd_nb_imports import *
from kret_sklearn.sklearn_nb_imports import *
from kret_type_hints.types_nb_imports import *
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/kretsinger/kret_sklearn/notebooks/.env
# [kret_matplotlib.mpl_nb_imports] Imported kret_matplotlib.mpl_nb_imports in 1.8897 seconds
# [kret_np_pd.np_pd_nb_imports] Imported kret_np_pd.np_pd_nb_imports in 1.0608 seconds
# [kret_sklearn.sklearn_nb_imports] Imported kret_sklearn.sklearn_nb_imports in 0.4601 seconds
# [kret_type_hints.types_nb_imports] Imported kret_type_hints.types_nb_imports in 0.0009 seconds

# %%
x, y = sklearn.datasets.make_sparse_uncorrelated(n_samples=20, n_features=5, random_state=42)

# %%
xdf = pd.DataFrame(x)

# %%
UKS_MPL.heatmap_styler(xdf)
# Out:
# <style type="text/css">
# #T_98ba7_row0_col0 {
#   background-color: #cee7ce;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row0_col1 {
#   background-color: #fff2f2;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row0_col2 {
#   background-color: #c0e0c0;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row0_col3 {
#   background-color: #6ab56a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row0_col4, #T_98ba7_row1_col0, #T_98ba7_row4_col1, #T_98ba7_row19_col4 {
#   background-color: #ffe8e8;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row1_col1 {
#   background-color: #64b264;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row1_col2 {
#   background-color: #b4dab4;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row1_col3, #T_98ba7_row2_col0, #T_98ba7_row2_col1, #T_98ba7_row9_col1 {
#   background-color: #ffd2d2;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row1_col4 {
#   background-color: #cae5ca;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row2_col2 {
#   background-color: #e8f4e8;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row2_col3 {
#   background-color: #ff4444;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row2_col4 {
#   background-color: #ff5656;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row3_col0 {
#   background-color: #ffc8c8;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row3_col1 {
#   background-color: #ff9c9c;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row3_col2, #T_98ba7_row10_col0 {
#   background-color: #e0f0e0;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row3_col3 {
#   background-color: #ffa6a6;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row3_col4, #T_98ba7_row4_col3 {
#   background-color: #ff7474;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row4_col0 {
#   background-color: #70b870;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row4_col2 {
#   background-color: #f8fcf8;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row4_col4 {
#   background-color: #ffcaca;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row5_col0 {
#   background-color: #f4faf4;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row5_col1 {
#   background-color: #ff8e8e;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row5_col2 {
#   background-color: #daedda;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row5_col3, #T_98ba7_row6_col0 {
#   background-color: #ffc4c4;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row5_col4, #T_98ba7_row8_col3, #T_98ba7_row15_col2 {
#   background-color: #ffe2e2;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row6_col1 {
#   background-color: #4aa54a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row6_col2 {
#   background-color: #fffefe;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row6_col3 {
#   background-color: #ff9898;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row6_col4, #T_98ba7_row15_col0 {
#   background-color: #aed7ae;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row7_col0 {
#   background-color: #ff8888;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row7_col1 {
#   background-color: #eaf5ea;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row7_col2 {
#   background-color: #ff4040;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row7_col3 {
#   background-color: #ff7e7e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row7_col4 {
#   background-color: #ecf6ec;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row8_col0 {
#   background-color: #b6dbb6;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row8_col1 {
#   background-color: #eef7ee;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row8_col2 {
#   background-color: #fff4f4;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row8_col4 {
#   background-color: #ff6e6e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row9_col0 {
#   background-color: #ffb8b8;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row9_col2 {
#   background-color: #98cc98;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row9_col3, #T_98ba7_row11_col3, #T_98ba7_row17_col2 {
#   background-color: #deefde;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row9_col4 {
#   background-color: #ff5252;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row10_col1 {
#   background-color: #ffdada;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row10_col2 {
#   background-color: #ffbcbc;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row10_col3 {
#   background-color: #c4e2c4;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row10_col4 {
#   background-color: #9acd9a;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row11_col0 {
#   background-color: #a4d2a4;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row11_col1 {
#   background-color: #ffacac;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row11_col2 {
#   background-color: #ffe0e0;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row11_col4, #T_98ba7_row18_col1 {
#   background-color: #a0d0a0;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row12_col0 {
#   background-color: #ffd0d0;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row12_col1 {
#   background-color: #ffecec;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row12_col2 {
#   background-color: #ff9292;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row12_col3 {
#   background-color: #ff8a8a;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row12_col4 {
#   background-color: #b0d8b0;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row13_col0 {
#   background-color: #7abd7a;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row13_col1 {
#   background-color: #fff8f8;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row13_col2 {
#   background-color: #9cce9c;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row13_col3, #T_98ba7_row14_col0, #T_98ba7_row16_col1 {
#   background-color: #dceedc;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row13_col4 {
#   background-color: #ffc0c0;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row14_col1 {
#   background-color: #68b468;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row14_col2 {
#   background-color: #fffcfc;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row14_col3 {
#   background-color: #66b366;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row14_col4 {
#   background-color: #ff0000;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row15_col1, #T_98ba7_row15_col3, #T_98ba7_row18_col0 {
#   background-color: #f6fbf6;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row15_col4 {
#   background-color: #ff3c3c;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row16_col0 {
#   background-color: #ffeaea;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row16_col2 {
#   background-color: #6eb76e;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row16_col3, #T_98ba7_row17_col3 {
#   background-color: #ffcccc;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row16_col4 {
#   background-color: #ffb0b0;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row17_col0 {
#   background-color: #ffcece;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row17_col1 {
#   background-color: #a6d3a6;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row17_col4 {
#   background-color: #cce6cc;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row18_col2 {
#   background-color: #ffbaba;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row18_col3 {
#   background-color: #ffdede;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row18_col4 {
#   background-color: #ffd8d8;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row19_col0 {
#   background-color: #ff7070;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_98ba7_row19_col1 {
#   background-color: #e2f1e2;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row19_col2 {
#   background-color: #e6f3e6;
#   color: #000000;
#   text-align: center;
# }
# #T_98ba7_row19_col3 {
#   background-color: #fefffe;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_98ba7">
#   <caption>
#         <div style="margin-top:6px; margin-bottom:12px;">
#         <div style="height:14px; border:1px solid #ccc;
