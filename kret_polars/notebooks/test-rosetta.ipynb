# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
from kret_notebook import *  # NOTE import first
from kret_matplotlib.mpl_nb_imports import *
from kret_np_pd.np_pd_nb_imports import *
from kret_polars.polars_nb_imports import *
from kret_sklearn.sklearn_nb_imports import *
from kret_torch_utils.torch_nb_imports import *
from kret_lightning.lightning_nb_imports import *
from kret_tqdm.tqdm_nb_imports import *
from kret_type_hints.types_nb_imports import *
from kret_utils.utils_nb_imports import *

# from kret_wandb.wandb_nb_imports import *  # NOTE this is slow to import
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/kretsinger/.env
# [kret_matplotlib.mpl_nb_imports] Imported kret_matplotlib.mpl_nb_imports in 0.0590 seconds
# [kret_np_pd.np_pd_nb_imports] Imported kret_np_pd.np_pd_nb_imports in 0.0000 seconds
# [kret_polars.polars_nb_imports] Imported kret_polars.polars_nb_imports in 0.0637 seconds
# [kret_sklearn.sklearn_nb_imports] Imported kret_sklearn.sklearn_nb_imports in 0.2189 seconds
# [kret_torch_utils.torch_nb_imports] Imported kret_torch_utils.torch_nb_imports in 0.3312 seconds
# [kret_lightning.lightning_nb_imports] Imported kret_lightning.lightning_nb_imports in 0.0011 seconds
# [kret_tqdm.tqdm_nb_imports] Imported kret_tqdm.tqdm_nb_imports in 0.0000 seconds
# [kret_type_hints.types_nb_imports] Imported kret_type_hints.types_nb_imports in 0.0003 seconds
# [kret_utils.utils_nb_imports] Imported kret_utils.utils_nb_imports in 0.0002 seconds

# %%
import polars as pl

df = pl.DataFrame(
    {
        "x": [1, 2, 3, 4],
        "y": [10, 20, 30, 40],
        "group": ["a", "a", "b", "b"],
    }
)

df
# Out:
# shape: (4, 3)
# ┌─────┬─────┬───────┐
# │ x   ┆ y   ┆ group │
# │ --- ┆ --- ┆ ---   │
# │ i64 ┆ i64 ┆ str   │
# ╞═════╪═════╪═══════╡
# │ 1   ┆ 10  ┆ a     │
# │ 2   ┆ 20  ┆ a     │
# │ 3   ┆ 30  ┆ b     │
# │ 4   ┆ 40  ┆ b     │
# └─────┴─────┴───────┘

# %%
df["x_plus_y"] = df["x"] + df["y"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dj/k5kk5wk90vvcnb_wphpw490r0000gn/T/ipykernel_51463/3324915423.py in ?()
# ----> 1 df['x_plus_y'] = df['x'] + df['y']
#
# ~/micromamba/envs/kret_312/lib/python3.12/site-packages/polars/dataframe/frame.py in ?(self, key, value)
#    1505             msg = (
#    1506                 "DataFrame object does not support `Series` assignment by index"
#    1507                 "\n\nUse `DataFrame.with_columns`."
#    1508             )
# -> 1509             raise TypeError(msg)
#    1510
#    1511         # df[["C", "D"]]
#    1512         elif isinstance(key, list):
#
# TypeError: DataFrame object does not support `Series` assignment by index
#
# Use `DataFrame.with_columns`.

# %% [markdown]
# # Load Data

# %% [markdown]
# # Implementation

# %% [markdown]
# # Sandbox
