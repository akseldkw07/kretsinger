# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from kret_notebook import *  # NOTE import first
from kret_matplotlib.mpl_nb_imports import *
from kret_np_pd.np_pd_nb_imports import *
from kret_sklearn.sklearn_nb_imports import *
from kret_type_hints.types_nb_imports import *
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/kretsinger/kret_sklearn/notebooks/.env
# [kret_matplotlib.mpl_nb_imports] Imported kret_matplotlib.mpl_nb_imports in 2.9184 seconds
# [kret_np_pd.np_pd_nb_imports] Imported kret_np_pd.np_pd_nb_imports in 0.0027 seconds
# [kret_sklearn.sklearn_nb_imports] Imported kret_sklearn.sklearn_nb_imports in 0.4859 seconds
# [kret_type_hints.types_nb_imports] Imported kret_type_hints.types_nb_imports in 0.0012 seconds

# %%
import sklearn.datasets


x, y = sklearn.datasets.make_sparse_uncorrelated(n_samples=100, n_features=20, random_state=42)

# %%
xdf = pd.DataFrame(x)

# %%
UKS_MPL.heatmap_styler(xdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/coding/kretsinger/kret_type_hints/typed_dict_utils.py:107, in TypedDictUtils._get_typeddict_keys(cls, typed_dict_class)
#     106 try:
# --> 107     hints = get_type_hints(typed_dict_class)
#     108     return set(hints.keys())
#
# File ~/micromamba/envs/kret_312/lib/python3.12/typing.py:2277, in get_type_hints(obj, globalns, localns, include_extras)
#    2276     value = ForwardRef(value, is_argument=False, is_class=True)
# -> 2277 value = _eval_type(value, base_globals, base_locals, base.__type_params__)
#    2278 hints[name] = value
#
# File ~/micromamba/envs/kret_312/lib/python3.12/typing.py:415, in _eval_type(t, globalns, localns, type_params, recursive_guard)
#     414 if isinstance(t, ForwardRef):
# --> 415     return t._evaluate(globalns, localns, type_params, recursive_guard=recursive_guard)
# ...

# %%
from pandas.io.formats.style import Styler
