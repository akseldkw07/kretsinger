# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
from kret_notebook import *  # NOTE import first
from kret_matplotlib.mpl_nb_imports import *
from kret_np_pd.np_pd_nb_imports import *
from kret_polars.polars_nb_imports import *
from kret_rosetta.rosetta_nb_imports import *
from kret_sklearn.sklearn_nb_imports import *
from kret_torch_utils.torch_nb_imports import *
from kret_lightning.lightning_nb_imports import *
from kret_tqdm.tqdm_nb_imports import *
from kret_type_hints.types_nb_imports import *
from kret_utils.utils_nb_imports import *

# from kret_wandb.wandb_nb_imports import *  # NOTE this is slow to import
# Out:
# [kret_sklearn.sklearn_nb_imports] Imported kret_sklearn.sklearn_nb_imports in 0.0002 seconds
# [kret_torch_utils.torch_nb_imports] Imported kret_torch_utils.torch_nb_imports in 0.3742 seconds
# [kret_lightning.lightning_nb_imports] Imported kret_lightning.lightning_nb_imports in 0.0014 seconds
# [kret_tqdm.tqdm_nb_imports] Imported kret_tqdm.tqdm_nb_imports in 0.0000 seconds
# [kret_type_hints.types_nb_imports] Imported kret_type_hints.types_nb_imports in 0.0007 seconds
# [kret_utils.utils_nb_imports] Imported kret_utils.utils_nb_imports in 0.0004 seconds

# %% [markdown]
# # Sandbox

# %%
out = UTILS_sklearn.make_regression()

# %%
out_multi = UTILS_sklearn.make_multilabel_classification()

# %%
isinstance(out_multi, tuple)
# Out:
# True

# %%
UKS_NP_PD.dtt(out_multi)
# Out:
# <div style='display: flex; gap: 20px; overflow-x: auto;'>
#         <style>
#             table td, table th {
#                 max-width: 150px;
#                 overflow: hidden;
#                 white-space: nowrap;
#                 position: relative;
#             }
#             table td {
#                 text-overflow: ellipsis;
#             }
#             table td.truncated::after, table th.truncated::after {
#                 content: '';
#                 position: absolute;
#                 right: 0;
#                 top: 0;
#                 bottom: 0;
#                 width: 20px;
#                 background: linear-gradient(to right, transparent, rgba(255, 0, 0, 0.4));
#                 pointer-events: none;
#             }
#         </style>
#         <script>
#             (function() {
#                 // Wait for the DOM to be ready
#                 setTimeout(function() {
#                     document.querySelectorAll('table td, table th').forEach(function(cell) {
#                         if (cell.scrollWidth > cell.clientWidth) {
#                             cell.classList.add('truncated');
#                         }
#                     });
#                 }, 100);
#             })();
#         </script>
#         <div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#       <th>13</th>
#       <th>14</th>
#       <th>15</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>784</th>
#       <td>3.000</td>
#       <td>6.000</td>
#       <td>0.000</td>
#       <td>3.000</td>
#       <td>1.000</td>
#       <td>6.000</td>
#       <td>4.000</td>
#       <td>4.000</td>
#       <td>0.000</td>
#       <td>4.000</td>
#       <td>5.000</td>
#       <td>2.000</td>
#       <td>2.000</td>
#       <td>2.000</td>
#       <td>1.000</td>
#       <td>3.000</td>
#     </tr>
#     <tr>
#       <th>1769</th>
#       <td>3.000</td>
#       <td>7.000</td>
#       <td>1.000</td>
#       <td>6.000</td>
#       <td>6.000</td>
#       <td>5.000</td>
#       <td>2.000</td>
#       <td>4.000</td>
#       <td>0.000</td>
#       <td>3.000</td>
#       <td>3.000</td>
#       <td>3.000</td>
#       <td>2.000</td>
#       <td>5.000</td>
#       <td>1.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>5559</th>
#       <td>4.000</td>
#       <td>2.000</td>
#       <td>2.000</td>
#       <td>4.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>7.000</td>
#       <td>5.000</td>
#       <td>2.000</td>
#       <td>1.000</td>
#       <td>4.000</td>
#       <td>0.000</td>
#       <td>6.000</td>
#       <td>2.000</td>
#       <td>0.000</td>
#       <td>4.000</td>
#     </tr>
#     <tr>
#       <th>8519</th>
#       <td>2.000</td>
#       <td>0.000</td>
#       <td>5.000</td>
#       <td>5.000</td>
#       <td>4.000</td>
#       <td>0.000</td>
#       <td>7.000</td>
#       <td>5.000</td>
#       <td>4.000</td>
#       <td>0.000</td>
#       <td>1.000</td>
#       <td>2.000</td>
#       <td>0.000</td>
#       <td>8.000</td>
#       <td>0.000</td>
#       <td>5.000</td>
#     </tr>
#     <tr>
#       <th>9905</th>
#       <td>2.000</td>
#       <td>2.000</td>
#       <td>7.000</td>
#       <td>2.000</td>
#       <td>8.000</td>
#       <td>3.000</td>
#       <td>8.000</td>
#       <td>1.000</td>
#       <td>1.000</td>
#       <td>2.000</td>
#       <td>0.000</td>
#       <td>2.000</td>
#       <td>2.000</td>
#       <td>5.000</td>
#       <td>2.000</td>
#       <td>2.000</td>
#     </tr>
#   </tbody>
# </table></div><div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>784</th>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1769</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5559</th>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8519</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9905</th>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table></div><div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.194</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.252</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.213</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.192</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.149</td>
#     </tr>
#   </tbody>
# </table></div><div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.084</td>
#       <td>0.061</td>
#       <td>0.102</td>
#       <td>0.107</td>
#       <td>0.067</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.011</td>
#       <td>0.003</td>
#       <td>0.095</td>
#       <td>0.087</td>
#       <td>0.151</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.088</td>
#       <td>0.029</td>
#       <td>0.015</td>
#       <td>0.035</td>
#       <td>0.063</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>0.021</td>
#       <td>0.015</td>
#       <td>0.075</td>
#       <td>0.015</td>
#       <td>0.034</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>0.005</td>
#       <td>0.040</td>
#       <td>0.014</td>
#       <td>0.033</td>
#       <td>0.021</td>
#     </tr>
#   </tbody>
# </table></div></div>

# %%
out = sklearn.datasets.make_multilabel_classification(return_distributions=True)

# %%
len(out), type(out)
# Out:
# (4, tuple)

# %%
for val in out:
    print(val.shape, type(val))
# Out:
# (100, 20) <class 'numpy.ndarray'>
# (100, 5) <class 'numpy.ndarray'>
# (5,) <class 'numpy.ndarray'>
# (20, 5) <class 'numpy.ndarray'>
