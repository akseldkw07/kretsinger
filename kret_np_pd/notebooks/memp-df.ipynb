# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
from kret_notebook import *  # NOTE import first
from kret_matplotlib.mpl_nb_imports import *
from kret_np_pd.np_pd_nb_imports import *
from kret_polars.polars_nb_imports import *
from kret_rosetta.rosetta_nb_imports import *
from kret_lgbm.lgbm_nb_imports import *
from kret_sklearn.sklearn_nb_imports import *
from kret_torch_utils.torch_nb_imports import *
from kret_lightning.lightning_nb_imports import *
from kret_tqdm.tqdm_nb_imports import *
from kret_type_hints.types_nb_imports import *
from kret_utils.utils_nb_imports import *

# from kret_wandb.wandb_nb_imports import *  # NOTE this is slow to import
# Out:
# [kret_np_pd.np_pd_nb_imports] Imported kret_np_pd.np_pd_nb_imports in 0.0202 seconds
# Loaded environment variables from /Users/Akseldkw/coding/kretsinger/.env
# [kret_matplotlib.mpl_nb_imports] Imported kret_matplotlib.mpl_nb_imports in 0.0747 seconds
# [kret_polars.polars_nb_imports] Imported kret_polars.polars_nb_imports in 0.0650 seconds
# [kret_rosetta.rosetta_nb_imports] Imported kret_rosetta.rosetta_nb_imports in 0.0000 seconds
# [kret_lgbm.lgbm_nb_imports] Imported kret_lgbm.lgbm_nb_imports in 0.0004 seconds
# [kret_sklearn.sklearn_nb_imports] Imported kret_sklearn.sklearn_nb_imports in 0.1061 seconds
# [kret_torch_utils.torch_nb_imports] Imported kret_torch_utils.torch_nb_imports in 0.3188 seconds
# [kret_lightning.lightning_nb_imports] Imported kret_lightning.lightning_nb_imports in 0.0010 seconds
# [kret_tqdm.tqdm_nb_imports] Imported kret_tqdm.tqdm_nb_imports in 0.0001 seconds
# ...

# %%
import importlib

import kret_np_pd
import kret_np_pd.memo_df


importlib.reload(kret_np_pd.memo_df)
# Out:
# <module 'kret_np_pd.memo_df' from '/Users/Akseldkw/coding/kretsinger/kret_np_pd/memo_df.py'>

# %% [markdown]
# # Starting out

# %%
df = pd.DataFrame({"a": [1, 2, 3], "b": [4, 5, 6]})
aux = pd.DataFrame({"c": [10, 20, 30], "d": [40, 50, 60]})

# %%
memodf = MemoDataFrame({"data": df})

# %%
memodf
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
memodf.data
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# ## Test Class

# %%
class MyInputDict(InputTypedDict):
    aux: pd.DataFrame

# %%
class MyMemoDataFrame(MemoDataFrame[MyInputDict]):
    @memo_array
    def a_sq(self):
        print("Calculating a_sq")
        return self.data["a"] ** 2

    @memo_array
    def compute_sum(self):
        return (self.data.sum(axis=1) + self.inputs["aux"].sum(axis=1)).to_numpy()

# %%
memo2 = MyMemoDataFrame({"data": df, "aux": aux})

# %%
type(memo2.a_sq)
# Out:
# numpy.ndarray

# %%
dtt(memo2, n=2, how="sample")
# Out:
# <div style='display: flex; gap: 20px; overflow-x: auto;'>
#         <style>
#             table td, table th {
#                 max-width: 150px;
#                 overflow: hidden;
#                 white-space: nowrap;
#                 position: relative;
#             }
#             table td {
#                 text-overflow: ellipsis;
#             }
#             table td.truncated::after, table th.truncated::after {
#                 content: '';
#                 position: absolute;
#                 right: 0;
#                 top: 0;
#                 bottom: 0;
#                 width: 20px;
#                 background: linear-gradient(to right, transparent, rgba(255, 0, 0, 0.4));
#                 pointer-events: none;
#             }
#         </style>
#         <script>
#             (function() {
#                 // Wait for the DOM to be ready
#                 setTimeout(function() {
# ...

# %%
memo2
# Out:
#    a  b  a_sq
# 0  1  4     1
# 1  2  5     4
# 2  3  6     9

# %%
memo2._memo_dict
# Out:
# {'a_sq': array([1, 4, 9])}

# %%
memo2.clear()

# %%
memo2.a_sq
# Out:
# Calculating a_sq
# array([1, 4, 9])

# %%
memo2.data
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# # Sandbox

# %%
memo2.to_pandas()
# Out:
#    a  b  a_sq
# 0  1  4     1
# 1  2  5     4
# 2  3  6     9

# %%
from kret_rosetta.conversion_protocols import PandasConvertibleWithColumns, ImplementsToPandas

# %%
isinstance(memo2, PandasConvertibleWithColumns)
# Out:
# False

# %%
isinstance(memo2, ImplementsToPandas)
# Out:
# True

# %%
isinstance(TensorDatasetCustom, PandasConvertibleWithColumns)
# Out:
# True

# %%
isinstance(TensorDatasetCustom, ImplementsToPandas)
# Out:
# True
