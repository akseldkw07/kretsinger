# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from kret_np_pd.np_pd_nb_imports import *
from kret_np_pd.enriched_df import Enriched_DF
from kret_np_pd.translate_libraries import PD_NP_Torch_Translation

# %%
class TestDS(Enriched_DF):
    id: pd.Series
    a: pd.Series
    b: pd.Series

# %%
mytest = TestDS({"id": [1, 2, 3], "a": [4, 5, 6]})
# mytest = TestDS({'id':[1,2,3]})

# %%
arr = mytest.to_numpy()
arr.shape
# Out:
# (3, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.shape[1]
# Out:
# 2

# %%
flattened = arr.flatten()
flattened
# Out:
# array([1, 4, 2, 5, 3, 6])

# %%
len(flattened.shape)
# Out:
# 1

# %%
flattened.ndim
# Out:
# 1
