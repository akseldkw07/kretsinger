# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from kret_notebook import *  # NOTE import first
from kret_matplotlib.mpl_nb_imports import *
from kret_np_pd.np_pd_nb_imports import *
from kret_sklearn.sklearn_nb_imports import *
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/kretsinger/.env
# [kret_matplotlib.mpl_nb_imports] Imported kret_matplotlib.mpl_nb_imports in 2.5517 seconds
# [kret_np_pd.np_pd_nb_imports] Imported kret_np_pd.np_pd_nb_imports in 0.0031 seconds
# [kret_sklearn.sklearn_nb_imports] Imported kret_sklearn.sklearn_nb_imports in 0.4175 seconds

# %%
x, y = sklearn.datasets.make_sparse_uncorrelated(n_samples=100, n_features=20, random_state=42)

# %%
x2, y2 = sklearn.datasets.make_classification(
    n_samples=100, n_features=20, n_informative=10, n_redundant=5, random_state=42
)

# %%
dtt([x, x2], num_cols=1, titles=["Sparse Uncorrelated", "Classification"])
# Out:
# <div style='display: flex; flex-direction: column; gap: 20px; overflow-x: auto;'>
#         <style>
#             table td, table th {
#                 max-width: 150px;
#                 overflow: hidden;
#                 white-space: nowrap;
#                 position: relative;
#             }
#             table td {
#                 text-overflow: ellipsis;
#             }
#             table td.truncated::after, table th.truncated::after {
#                 content: '';
#                 position: absolute;
#                 right: 0;
#                 top: 0;
#                 bottom: 0;
#                 width: 20px;
#                 background: linear-gradient(to right, transparent, rgba(255, 0, 0, 0.4));
#                 pointer-events: none;
#             }
#         </style>
#         <script>
#             (function() {
#                 // Wait for the DOM to be ready
#                 setTimeout(function() {
# ...
