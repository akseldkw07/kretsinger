# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
from kret_notebook import *  # NOTE import first
from kret_lgbm._core.lgbm_nb_imports import *
from kret_lightning._core.lightning_nb_imports import *
from kret_matplotlib._core.mpl_nb_imports import *
from kret_np_pd._core.np_pd_nb_imports import *
from kret_optuna._core.optuna_nb_imports import *
from kret_polars._core.polars_nb_imports import *
from kret_rosetta._core.rosetta_nb_imports import *
from kret_sklearn._core.sklearn_nb_imports import *
from kret_torch_utils._core.torch_nb_imports import *
from kret_tqdm._core.tqdm_nb_imports import *
from kret_type_hints._core.types_nb_imports import *
from kret_utils._core.utils_nb_imports import *

# from kret_wandb._core.wandb_nb_imports import *  # NOTE this is slow to import
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/kretsinger/.env
# [kret_lgbm._core.lgbm_nb_imports] Imported kret_lgbm._core.lgbm_nb_imports in 2.1606 seconds
# [kret_lightning._core.lightning_nb_imports] Imported kret_lightning._core.lightning_nb_imports in 4.4798 seconds
# [kret_matplotlib._core.mpl_nb_imports] Imported kret_matplotlib._core.mpl_nb_imports in 0.2782 seconds
# [kret_np_pd._core.np_pd_nb_imports] Imported kret_np_pd._core.np_pd_nb_imports in 0.0005 seconds
# [kret_optuna._core.optuna_nb_imports] Imported kret_optuna._core.optuna_nb_imports in 0.0015 seconds
# [kret_polars._core.polars_nb_imports] Imported kret_polars._core.polars_nb_imports in 0.1123 seconds
# [kret_rosetta._core.rosetta_nb_imports] Imported kret_rosetta._core.rosetta_nb_imports in 0.0000 seconds
# [kret_sklearn._core.sklearn_nb_imports] Imported kret_sklearn._core.sklearn_nb_imports in 0.1947 seconds
# [kret_torch_utils._core.torch_nb_imports] Imported kret_torch_utils._core.torch_nb_imports in 0.4228 seconds
# [kret_tqdm._core.tqdm_nb_imports] Imported kret_tqdm._core.tqdm_nb_imports in 0.0002 seconds
# [kret_type_hints._core.types_nb_imports] Imported kret_type_hints._core.types_nb_imports in 0.0009 seconds
# [kret_utils._core.utils_nb_imports] Imported kret_utils._core.utils_nb_imports in 0.0011 seconds

# %% [markdown]
# # Implementation

# %%
out = UTILS_sklearn.make_regression()

# %%
out_multi = UTILS_sklearn.make_multilabel_classification()

# %%
isinstance(out_multi, tuple)
# Out:
# True

# %%
UKS_NP_PD.dtt(out_multi, show_dims=True, titles=["X_multi", "y_multi", "1", "2"])
# Out:
# <div id='dtt-262867'><div style='display: flex; gap: 20px; overflow-x: auto;'>
#         <style>
#             #dtt-262867 table td, #dtt-262867 table th {
#                 max-width: 150px;
#                 overflow: hidden;
#                 white-space: nowrap;
#                 position: relative;
#             }
#             #dtt-262867 table td {
#                 text-overflow: ellipsis;
#             }
#             #dtt-262867 table td.truncated::after, #dtt-262867 table th.truncated::after {
#                 content: '';
#                 position: absolute;
#                 right: 0;
#                 top: 0;
#                 bottom: 0;
#                 width: 20px;
#                 background: linear-gradient(to right, transparent, rgba(255, 0, 0, 0.4));
#                 pointer-events: none;
#             }
#         </style>
#         <script>
#             (function() {
#                 // Wait for the DOM to be ready
#                 setTimeout(function() {
#                     document.querySelectorAll('#dtt-262867 table td, #dtt-262867 table th').forEach(function(cell) {
#                         if (cell.scrollWidth > cell.clientWidth) {
#                             cell.classList.add('truncated');
#                             // Expand truncated cells up to max_col_width so content
#                             // is as visible as possible without forcing non-truncated
#                             // cells to be wider than their natural size
#                             cell.style.width = '150px';
#                         }
#                     });
#                 }, 100);
#             })();
#         </script>
#         <div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><div style="text-align: left; font-weight: bold; margin-left: 5px; font-size: 18px; margin-bottom: 8px;">X_multi</div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#       <th>13</th>
#       <th>14</th>
#       <th>15</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>759</th>
#       <td>6.000</td>
#       <td>1.000</td>
#       <td>4.000</td>
#       <td>5.000</td>
#       <td>4.000</td>
#       <td>2.000</td>
#       <td>3.000</td>
#       <td>2.000</td>
#       <td>3.000</td>
#       <td>2.000</td>
#       <td>1.000</td>
#       <td>1.000</td>
#       <td>2.000</td>
#       <td>7.000</td>
#       <td>0.000</td>
#       <td>2.000</td>
#     </tr>
#     <tr>
#       <th>5385</th>
#       <td>4.000</td>
#       <td>3.000</td>
#       <td>6.000</td>
#       <td>3.000</td>
#       <td>4.000</td>
#       <td>2.000</td>
#       <td>8.000</td>
#       <td>2.000</td>
#       <td>4.000</td>
#       <td>2.000</td>
#       <td>4.000</td>
#       <td>5.000</td>
#       <td>3.000</td>
#       <td>6.000</td>
#       <td>0.000</td>
#       <td>1.000</td>
#     </tr>
#     <tr>
#       <th>6485</th>
#       <td>5.000</td>
#       <td>5.000</td>
#       <td>1.000</td>
#       <td>5.000</td>
#       <td>2.000</td>
#       <td>2.000</td>
#       <td>4.000</td>
#       <td>4.000</td>
#       <td>3.000</td>
#       <td>2.000</td>
#       <td>6.000</td>
#       <td>1.000</td>
#       <td>2.000</td>
#       <td>10.000</td>
#       <td>1.000</td>
#       <td>1.000</td>
#     </tr>
#     <tr>
#       <th>6987</th>
#       <td>4.000</td>
#       <td>1.000</td>
#       <td>5.000</td>
#       <td>4.000</td>
#       <td>12.000</td>
#       <td>2.000</td>
#       <td>5.000</td>
#       <td>5.000</td>
#       <td>1.000</td>
#       <td>2.000</td>
#       <td>2.000</td>
#       <td>2.000</td>
#       <td>1.000</td>
#       <td>6.000</td>
#       <td>0.000</td>
#       <td>3.000</td>
#     </tr>
#     <tr>
#       <th>7436</th>
#       <td>4.000</td>
#       <td>9.000</td>
#       <td>2.000</td>
#       <td>4.000</td>
#       <td>1.000</td>
#       <td>4.000</td>
#       <td>9.000</td>
#       <td>0.000</td>
#       <td>1.000</td>
#       <td>0.000</td>
#       <td>2.000</td>
#       <td>1.000</td>
#       <td>6.000</td>
#       <td>1.000</td>
#       <td>2.000</td>
#       <td>7.000</td>
#     </tr>
#   </tbody>
#   <tfoot>
#     <tr><td colspan="17" style="text-align: left; font-size: 0.8em; color: #888; font-style: italic; padding: 4px 8px;">Showing 5 of 10000 rows × 16 columns</td></tr>
#   </tfoot>
# </table></div><div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><div style="text-align: left; font-weight: bold; margin-left: 5px; font-size: 18px; margin-bottom: 8px;">y_multi</div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#       <th>int64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>759</th>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5385</th>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6485</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6987</th>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7436</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#   </tbody>
#   <tfoot>
#     <tr><td colspan="6" style="text-align: left; font-size: 0.8em; color: #888; font-style: italic; padding: 4px 8px;">Showing 5 of 10000 rows × 5 columns</td></tr>
#   </tfoot>
# </table></div><div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><div style="text-align: left; font-weight: bold; margin-left: 5px; font-size: 18px; margin-bottom: 8px;">1</div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.194</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.252</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.213</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.192</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.149</td>
#     </tr>
#   </tbody>
#   <tfoot>
#     <tr><td colspan="2" style="text-align: left; font-size: 0.8em; color: #888; font-style: italic; padding: 4px 8px;">Showing 5 of 5 rows × 1 columns</td></tr>
#   </tfoot>
# </table></div><div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><div style="text-align: left; font-weight: bold; margin-left: 5px; font-size: 18px; margin-bottom: 8px;">2</div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0.104</td>
#       <td>0.074</td>
#       <td>0.065</td

# %%
str_arr = np.array(
    [
        "L2ndFloor-D-2022-01-24_T-14_30_02",
        "L2ndFloor-D-2022-01-31_T-14_30_02",
        "L2ndFloor-D-2021-12-25_T-14_00_01",
        "L2ndFloor-D-2021-12-25_T-18_30_01",
        "L2ndFloor-D-2022-03-14_T-18_00_01",
    ],
    dtype="<U33",
)

# %%
UKS_NP_PD.dtt([str_arr], titles=["str_arr"], show_dims=True, max_col_width=250)
# Out:
# <div id='dtt-394589'><div style='display: flex; gap: 20px; overflow-x: auto;'>
#         <style>
#             #dtt-394589 table td, #dtt-394589 table th {
#                 max-width: 250px;
#                 overflow: hidden;
#                 white-space: nowrap;
#                 position: relative;
#             }
#             #dtt-394589 table td {
#                 text-overflow: ellipsis;
#             }
#             #dtt-394589 table td.truncated::after, #dtt-394589 table th.truncated::after {
#                 content: '';
#                 position: absolute;
#                 right: 0;
#                 top: 0;
#                 bottom: 0;
#                 width: 20px;
#                 background: linear-gradient(to right, transparent, rgba(255, 0, 0, 0.4));
#                 pointer-events: none;
#             }
#         </style>
#         <script>
#             (function() {
#                 // Wait for the DOM to be ready
#                 setTimeout(function() {
#                     document.querySelectorAll('#dtt-394589 table td, #dtt-394589 table th').forEach(function(cell) {
#                         if (cell.scrollWidth > cell.clientWidth) {
#                             cell.classList.add('truncated');
#                             // Expand truncated cells up to max_col_width so content
#                             // is as visible as possible without forcing non-truncated
#                             // cells to be wider than their natural size
#                             cell.style.width = '250px';
#                         }
#                     });
#                 }, 100);
#             })();
#         </script>
#         <div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><div style="text-align: left; font-weight: bold; margin-left: 5px; font-size: 18px; margin-bottom: 8px;">str_arr</div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>str</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>L2ndFloor-D-2022-01-24_T-14_30_02</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>L2ndFloor-D-2022-01-31_T-14_30_02</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>L2ndFloor-D-2021-12-25_T-14_00_01</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>L2ndFloor-D-2021-12-25_T-18_30_01</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>L2ndFloor-D-2022-03-14_T-18_00_01</td>
#     </tr>
#   </tbody>
#   <tfoot>
#     <tr><td colspan="2" style="text-align: left; font-size: 0.8em; color: #888; font-style: italic; padding: 4px 8px;">Showing 5 of 5 rows × 1 columns</td></tr>
#   </tfoot>
# </table></div></div></div>

# %%
styler = UKS_MPL.heatmap_styler(out_multi.x, cmap="Reds")
# styler

# %%
UKS_NP_PD.dtt([styler, out_multi.x], titles=["styler", "data"], how="head")
# Out:
# <div id='dtt-411948'><div style='display: flex; gap: 20px; overflow-x: auto;'>
#         <style>
#             #dtt-411948 table td, #dtt-411948 table th {
#                 max-width: 150px;
#                 overflow: hidden;
#                 white-space: nowrap;
#                 position: relative;
#             }
#             #dtt-411948 table td {
#                 text-overflow: ellipsis;
#             }
#             #dtt-411948 table td.truncated::after, #dtt-411948 table th.truncated::after {
#                 content: '';
#                 position: absolute;
#                 right: 0;
#                 top: 0;
#                 bottom: 0;
#                 width: 20px;
#                 background: linear-gradient(to right, transparent, rgba(255, 0, 0, 0.4));
#                 pointer-events: none;
#             }
#         </style>
#         <script>
#             (function() {
#                 // Wait for the DOM to be ready
#                 setTimeout(function() {
#                     document.querySelectorAll('#dtt-411948 table td, #dtt-411948 table th').forEach(function(cell) {
#                         if (cell.scrollWidth > cell.clientWidth) {
#                             cell.classList.add('truncated');
#                             // Expand truncated cells up to max_col_width so content
#                             // is as visible as possible without forcing non-truncated
#                             // cells to be wider than their natural size
#                             cell.style.width = '150px';
#                         }
#                     });
#                 }, 100);
#             })();
#         </script>
#         <div style='flex: 0 0 auto; min-width: 30px; border-left: 2px solid #ccc; padding-left: 0px;'><div style="text-align: left; font-weight: bold; margin-left: 5px; font-size: 18px; margin-bottom: 8px;">styler</div><style type="text/css">
# #T_8eb70_row0_col0, #T_8eb70_row0_col6, #T_8eb70_row0_col10, #T_8eb70_row0_col15, #T_8eb70_row1_col5, #T_8eb70_row1_col8, #T_8eb70_row1_col9, #T_8eb70_row2_col0, #T_8eb70_row2_col7, #T_8eb70_row2_col12, #T_8eb70_row2_col15, #T_8eb70_row3_col6, #T_8eb70_row4_col1, #T_8eb70_row4_col8, #T_8eb70_row4_col12, #T_8eb70_row4_col13 {
#   background-color: #fdd4c2;
#   color: #000000;
#   text-align: center;
# }
# #T_8eb70_row0_col1, #T_8eb70_row0_col11, #T_8eb70_row0_col12, #T_8eb70_row0_col14, #T_8eb70_row3_col11, #T_8eb70_row3_col14, #T_8eb70_row4_col10 {
#   background-color: #fff5f0;
#   color: #000000;
#   text-align: center;
# }
# #T_8eb70_row0_col2, #T_8eb70_row1_col3, #T_8eb70_row1_col6, #T_8eb70_row1_col12, #T_8eb70_row2_col2, #T_8eb70_row3_col0, #T_8eb70_row3_col2, #T_8eb70_row3_col4, #T_8eb70_row3_col7, #T_8eb70_row3_col8, #T_8eb70_row4_col0 {
#   background-color: #fcc4ad;
#   color: #000000;
#   text-align: center;
# }
# #T_8eb70_row0_col3, #T_8eb70_row0_col8, #T_8eb70_row1_col4, #T_8eb70_row1_col7, #T_8eb70_row1_col10, #T_8eb70_row1_col11, #T_8eb70_row2_col9, #T_8eb70_row2_col10, #T_8eb70_row3_col10, #T_8eb70_row3_col12, #T_8eb70_row4_col7 {
#   background-color: #fee3d6;
#   color: #000000;
#   text-align: center;
# }
# #T_8eb70_row0_col4, #T_8eb70_row0_col13, #T_8eb70_row1_col13, #T_8eb70_row1_col15, #T_8eb70_row2_col1, #T_8eb70_row2_col3, #T_8eb70_row2_col4, #T_8eb70_row2_col6, #T_8eb70_row2_col13, #T_8eb70_row3_col1, #T_8eb70_row3_col3, #T_8eb70_row4_col3, #T_8eb70_row4_col4 {
#   background-color: #fcb296;
#   color: #000000;
#   text-align: center;
# }
# #T_8eb70_row0_col5, #T_8eb70_row1_col1, #T_8eb70_row1_col14, #T_8eb70_row2_col5, #T_8eb70_row2_col8, #T_8eb70_row2_col11, #T_8eb70_row2_col14, #T_8eb70_row3_col5, #T_8eb70_row3_col9, #T_8eb70_row4_col2, #T_8eb70_row4_col5, #T_8eb70_row4_col11, #T_8eb70_row4_col14, #T_8eb70_row4_col15 {
#   background-color: #ffece3;
#   color: #000000;
#   text-align: center;
# }
# #T_8eb70_row0_col7 {
#   background-color: #fb694a;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_8eb70_row0_col9, #T_8eb70_row1_col0, #T_8eb70_row4_col6 {
#   background-color: #fca082;
#   color: #000000;
#   text-align: center;
# }
# #T_8eb70_row1_col2, #T_8eb70_row3_col15, #T_8eb70_row4_col9 {
#   background-color: #fc8e6e;
#   color: #000000;
#   text-align: center;
# }
# #T_8eb70_row3_col13 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
#   text-align: center;
# }
# </style>
# <table id="T_8eb70">
#   <caption>
#         <div style="margin-top:6px; margin-bottom:12px;">
#         <div style="height:14px; border:1px solid #ccc;
#                     background: linear-gradient(to right, #ffffff, #fefffe, #fdfefd, #fcfefc, #fbfdfb, #fafdfa, #f9fcf9, #f8fcf8, #f7fbf7, #f6fbf6, #f5faf5, #f4faf4, #f3f9f3, #f2f9f2, #f1f8f1, #f0f8f0, #eff7ef, #eef7ee, #edf6ed, #ecf6ec, #ebf5eb, #eaf5ea, #e9f4e9, #e8f4e8, #e7f3e7, #e6f3e6, #e5f2e5, #e4f2e4, #e3f1e3, #e2f1e2, #e1f0e1, #e0f0e0,