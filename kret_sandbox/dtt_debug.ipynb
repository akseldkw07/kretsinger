# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from kret_studies import *
from kret_studies.notebook import *
from kret_studies.complex import *

logger = get_notebook_logger()
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/kretsinger/.env.
# INFO:datasets:JAX version 0.7.2 available.

# %%
DEVICE_TORCH_STR
# Out:
# 'mps'

# %%
from VIS import dtt
from itertools import chain, cycle
from VIS import gen_display_mask, generate_table_with_dtypes, fmt_css, DTTParams
from IPython.display import display_html

# %%
import time

# Create large datasets
large_df = pd.DataFrame({f"col_{i}": np.random.randn(10000) for i in range(50)})

large_tensor = torch.randn(5000, 30)
large_np = np.random.randn(8000, 20)

# Time the rendering
start = time.time()

elapsed = time.time() - start

print(f"\nRendering time: {elapsed:.3f} seconds")
print(f"Expected: < 1 second for optimized version")
# Out:
# Rendering time: 0.000 seconds
# Expected: < 1 second for optimized version

# %%
titles = ["Large DF (10k x 50)", "Large Tensor (5k x 30)", "Large NumPy (8k x 20)"]

# %%
dtt(
    [large_df, large_tensor, large_np],
    n=20,
    num_cols=2,
    round_float=3,
    titles=titles,
)
# Out:
# <div style="display: flex; gap: 20px; overflow-x: auto;">
#         <style>
#             table td, table th {
#                 max-width: 150px;
#                 overflow: hidden;
#                 white-space: nowrap;
#                 position: relative;
#             }
#             table td {
#                 text-overflow: ellipsis;
#             }
#             table td.truncated::after, table th.truncated::after {
#                 content: '';
#                 position: absolute;
#                 right: 0;
#                 top: 0;
#                 bottom: 0;
#                 width: 20px;
#                 background: linear-gradient(to right, transparent, rgba(255, 0, 0, 0.4));
#                 pointer-events: none;
#             }
#         </style>
#         <script>
#             (function() {
#                 // Wait for the DOM to be ready
#                 setTimeout(function() {
#                     document.querySelectorAll('table td, table th').forEach(function(cell) {
#                         if (cell.scrollWidth > cell.clientWidth) {
#                             cell.classList.add('truncated');
#                         }
#                     });
#                 }, 100);
#             })();
#         </script>
#         <div style="flex: 0 0 auto; min-width: 30px;"><div style="text-align: left; font-weight: bold; font-size: 18px; margin-bottom: 8px;">Large DF (10k x 50)</div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col_0</th>
#       <th>col_1</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>float64</th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>430</th>
#       <td>-0.112</td>
#       <td>0.716</td>
#     </tr>
#     <tr>
#       <th>893</th>
#       <td>-0.689</td>
#       <td>0.031</td>
#     </tr>
#     <tr>
#       <th>2941</th>
#       <td>-0.903</td>
#       <td>-0.625</td>
#     </tr>
#     <tr>
#       <th>2984</th>
#       <td>-0.528</td>
#       <td>-1.738</td>
#     </tr>
#     <tr>
#       <th>3306</th>
#       <td>0.654</td>
#       <td>0.437</td>
#     </tr>
#     <tr>
#       <th>4393</th>
#       <td>2.078</td>
#       <td>0.486</td>
#     </tr>
#     <tr>
#       <th>4394</th>
#       <td>0.789</td>
#       <td>-0.442</td>
#     </tr>
#     <tr>
#       <th>4708</th>
#       <td>2.208</td>
#       <td>-0.437</td>
#     </tr>
#     <tr>
#       <th>5022</th>
#       <td>0.950</td>
#       <td>-0.083</td>
#     </tr>
#     <tr>
#       <th>5726</th>
#       <td>-1.175</td>
#       <td>-0.296</td>
#     </tr>
#     <tr>
#       <th>6493</th>
#       <td>-0.575</td>
#       <td>0.516</td>
#     </tr>
#     <tr>
#       <th>7103</th>
#       <td>-1.687</td>
#       <td>-0.296</td>
#     </tr>
#     <tr>
#       <th>7432</th>
#       <td>1.032</td>
#       <td>0.108</td>
#     </tr>
#     <tr>
#       <th>7536</th>
#       <td>0.835</td>
#       <td>0.592</td>
#     </tr>
#     <tr>
#       <th>7694</th>
#       <td>1.198</td>
#       <td>0.922</td>
#     </tr>
#     <tr>
#       <th>7927</th>
#       <td>-1.288</td>
#       <td>-0.750</td>
#     </tr>
#     <tr>
#       <th>8497</th>
#       <td>1.880</td>
#       <td>-0.148</td>
#     </tr>
#     <tr>
#       <th>8971</th>
#       <td>-0.002</td>
#       <td>0.337</td>
#     </tr>
#     <tr>
#       <th>9535</th>
#       <td>0.920</td>
#       <td>1.221</td>
#     </tr>
#     <tr>
#       <th>9993</th>
#       <td>-1.567</td>
#       <td>-0.766</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col_2</th>
#       <th>col_3</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>float64</th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>430</th>
#       <td>0.736</td>
#       <td>-0.928</td>
#     </tr>
#     <tr>
#       <th>893</th>
#       <td>-1.197</td>
#       <td>0.753</td>
#     </tr>
#     <tr>
#       <th>2941</th>
#       <td>1.480</td>
#       <td>1.510</td>
#     </tr>
#     <tr>
#       <th>2984</th>
#       <td>-1.512</td>
#       <td>1.531</td>
#     </tr>
#     <tr>
#       <th>3306</th>
#       <td>0.214</td>
#       <td>1.381</td>
#     </tr>
#     <tr>
#       <th>4393</th>
#       <td>0.397</td>
#       <td>-1.755</td>
#     </tr>
#     <tr>
#       <th>4394</th>
#       <td>-0.633</td>
#       <td>-0.753</td>
#     </tr>
#     <tr>
#       <th>4708</th>
#       <td>1.357</td>
#       <td>-2.134</td>
#     </tr>
#     <tr>
#       <th>5022</th>
#       <td>0.873</td>
#       <td>-0.455</td>
#     </tr>
#     <tr>
#       <th>5726</th>
#       <td>1.755</td>
#       <td>-0.427</td>
#     </tr>
#     <tr>
#       <th>6493</th>
#       <td>0.678</td>
#       <td>0.281</td>
#     </tr>
#     <tr>
#       <th>7103</th>
#       <td>0.210</td>
#       <td>-1.466</td>
#     </tr>
#     <tr>
#       <th>7432</th>
#       <td>-0.973</td>
#       <td>0.824</td>
#     </tr>
#     <tr>
#       <th>7536</th>
#       <td>1.450</td>
#       <td>0.682</td>
#     </tr>
#     <tr>
#       <th>7694</th>
#       <td>0.094</td>
#       <td>1.519</td>
#     </tr>
#     <tr>
#       <th>7927</th>
#       <td>-0.913</td>
#       <td>1.770</td>
#     </tr>
#     <tr>
#       <th>8497</th>
#       <td>0.406</td>
#       <td>-2.914</td>
#     </tr>
#     <tr>
#       <th>8971</th>
#       <td>-0.121</td>
#       <td>0.284</td>
#     </tr>
#     <tr>
#       <th>9535</th>
#       <td>-1.408</td>
#       <td>0.798</td>
#     </tr>
#     <tr>
#       <th>9993</th>
#       <td>-0.025</td>
#       <td>-0.181</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col_4</th>
#       <th>col_5</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>float64</th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>430</th>
#       <td>0.727</td>
#       <td>-0.352</td>
#     </tr>
#     <tr>
#       <th>893</th>
#       <td>-0.294</td>
#       <td>-0.881</td>
#     </tr>
#     <tr>
#       <th>2941</th>
#       <td>-0.369</td>
#       <td>-0.153</td>
#     </tr>
#     <tr>
#       <th>2984</th>
#       <td>-0.898</td>
#       <td>0.088</td>
#     </tr>
#     <tr>
#       <th>3306</th>
#       <td>0.233</td>
#       <td>-0.980</td>
#     </tr>
#     <tr>
#       <th>4393</th>
#       <td>-0.632</td>
#       <td>-0.946</td>
#     </tr>
#     <tr>
#       <th>4394</th>
#       <td>0.388</td>
#       <td>1.261</td>
#     </tr>
#     <tr>
#       <th>4708</th>
#       <td>0.157</td>
#       <td>0.942</td>
#     </tr>
#     <tr>
#       <th>5022</th>
#       <td>1.006</td>
#       <td>0.522</td>
#     </tr>
#     <tr>
#       <th>5726</th>
#       <td>-0.035</td>
#       <td>0.935</td>
#     </tr>
#     <tr>
#       <th>6493</th>
#       <td>0.538</td>
#       <td>-0.081</td>
#     </tr>
#     <tr>
#       <th>7103</th>
#       <td>-1.477</td>
#       <td>0.134</td>
#     </tr>
#     <tr>
#       <th>7432</th>
#       <td>-0.729</td>
#       <td>0.744</td>
#     </tr>
#     <tr>
#       <th>7536</th>
#       <td>0.638</td>
#       <td>-0.668</td>
#     </tr>
#     <tr>
#       <th>7694</th>
#       <td>1.377</td>
#       <td>-0.751</td>
#     </tr>
#     <tr>
#       <th>7927</th>
#       <td>-0.244</td>
#       <td>-0.009</td>
#     </tr>
#     <tr>
#       <th>8497</th>
#       <td>1.594</td>
#       <td>-0.582</td>
#     </tr>
#     <tr>
#       <th>8971</th>
#       <td>1.041</td>
#       <td>-1.087</td>
#     </tr>
#     <tr>
#       <th>9535</th>
#       <td>-0.736</td>
#       <td>0.290</td>
#     </tr>
#     <tr>
#       <th>9993</th>
#       <td>-0.509</td>
#       <td>-0.316</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col_6</th>
#       <th>col_7</th>
#     </tr>
#     <tr style="text-align: right; font-size: 0.85em; color: #666; font-style: italic;">
#       <th></th>
#       <th>float64</th>
#       <th>float64</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>430</th>
#       <td>-0.433</td>
#       <td>0.763</td>
#     </tr>
#     <tr>
#       <th>893</th>
#       <td>-1.107</td>
#       <td>-0.113</td>
#     </tr>
#     <tr>
#       <th>2941</th>
#       <td>0.285</td>
#       <td>-0.672</td>
#     </tr>
#     <tr>
#       <th>2984</th>
#       <td>-0.072</td>
#       <td>1.852</td>
#     </tr>
#     <tr>

# %% [markdown]
# # DEBUG

# %%
len(args)
# Out:
# 3

# %%
hparams: DTTParams = {}

# %%
# Add overflow-x: auto for horizontal scrolling
html_str = '<div style="display: flex; gap: 20px; overflow-x: auto;">'
html_str = fmt_css(hparams, html_str)

# %%
seed = 0
n = 4
how = "head"

# %%
for df, title in zip(args, chain(titles, cycle([""]))):
    # Add flex-shrink: 0 to prevent tables from shrinking
    html_str += '<div style="flex: 0 0 auto; min-width: 30px;">'

    if title:
        html_str += (
            f'<div style="text-align: left; font-weight: bold; font-size: 18px; margin-bottom: 8px;">{title}</div>'
        )

    mask = gen_display_mask(len(df), min(n, len(df)), seed, how)
    table_html = generate_table_with_dtypes(df[mask])
    html_str += table_html
    html_str += "</div>"
html_str += "</div>"

# %%
display_html(html_str, raw=True)
# Out:
# <div style="display: flex; gap: 20px; overflow-x: auto;"><div style="flex: 0 0 auto; min-width: 30px;"><div style="text-align: left; font-weight: bold; font-size: 18px; margin-bottom: 8px;">Large DF (10k x 50)</div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col_0</th>
#       <th>col_1</th>
#       <th>col_2</th>
#       <th>col_3</th>
#       <th>col_4</th>
#       <th>col_5</th>
#       <th>col_6</th>
#       <th>col_7</th>
#       <th>col_8</th>
#       <th>col_9</th>
#       <th>col_10</th>
#       <th>col_11</th>
#       <th>col_12</th>
#       <th>col_13</th>
#       <th>col_14</th>
#       <th>col_15</th>
#       <th>col_16</th>
#       <th>col_17</th>
#       <th>col_18</th>
#       <th>col_19</th>
#       <th>col_20</th>
#       <th>col_21</th>
#       <th>col_22</th>
#       <th>col_23</th>
#       <th>col_24</th>
