# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
from kret_notebook import *  # NOTE import first
from kret_lgbm._core.lgbm_nb_imports import *
from kret_lightning._core.lightning_nb_imports import *
from kret_matplotlib._core.mpl_nb_imports import *
from kret_np_pd._core.np_pd_nb_imports import *
from kret_optuna._core.optuna_nb_imports import *
from kret_polars._core.polars_nb_imports import *
from kret_rosetta._core.rosetta_nb_imports import *
from kret_sklearn._core.sklearn_nb_imports import *
from kret_torch_utils._core.torch_nb_imports import *
from kret_tqdm._core.tqdm_nb_imports import *
from kret_type_hints._core.types_nb_imports import *
from kret_utils._core.utils_nb_imports import *

# from kret_wandb._core.wandb_nb_imports import *  # NOTE this is slow to import
# Out:
# Loaded environment variables from /Users/Akseldkw/coding/kretsinger/.env
# [kret_lgbm._core.lgbm_nb_imports] Imported kret_lgbm._core.lgbm_nb_imports in 1.7220 seconds
# [kret_np_pd._core.np_pd_nb_imports] Imported kret_np_pd._core.np_pd_nb_imports in 0.0262 seconds
# [kret_lightning._core.lightning_nb_imports] Imported kret_lightning._core.lightning_nb_imports in 3.7137 seconds
# [kret_matplotlib._core.mpl_nb_imports] Imported kret_matplotlib._core.mpl_nb_imports in 0.0840 seconds
# [kret_optuna._core.optuna_nb_imports] Imported kret_optuna._core.optuna_nb_imports in 0.0004 seconds
# [kret_polars._core.polars_nb_imports] Imported kret_polars._core.polars_nb_imports in 0.0911 seconds
# [kret_rosetta._core.rosetta_nb_imports] Imported kret_rosetta._core.rosetta_nb_imports in 0.0000 seconds
# [kret_sklearn._core.sklearn_nb_imports] Imported kret_sklearn._core.sklearn_nb_imports in 0.1530 seconds
# [kret_torch_utils._core.torch_nb_imports] Imported kret_torch_utils._core.torch_nb_imports in 0.5025 seconds
# [kret_tqdm._core.tqdm_nb_imports] Imported kret_tqdm._core.tqdm_nb_imports in 0.0002 seconds
# [kret_type_hints._core.types_nb_imports] Imported kret_type_hints._core.types_nb_imports in 0.0008 seconds
# [kret_utils._core.utils_nb_imports] Imported kret_utils._core.utils_nb_imports in 0.0007 seconds

# %%
import sys

# Get all imported modules
imported_modules = sys.modules.keys()

# Filter to show only the main packages (not submodules)
main_packages = sorted([mod.split(".")[0] for mod in imported_modules if not mod.startswith("_")])

# Remove duplicates
main_packages = sorted(set(main_packages))

print("Imported packages:")
for pkg in main_packages:
    print(f"  {pkg}")
# Out:
# Imported packages:
#   Cython
#   IPython
#   PIL
#   abc
#   accelerate
#   aiohappyeyeballs
#   aiohttp
#   aiosignal
#   appnope
#   argparse
#   array
#   ast
#   asttokens
#   asyncio
#   atexit
#   attr
#   backports
#   base64
#   bdb
#   binascii
#   bisect
#   brotli
#   builtins
#   bz2
#   cProfile
#   calendar
#   certifi
#   cffi
#   chardet
#   charset_normalizer
#   click
#   cloudpickle
#   cmath
#   cmd
#   code
#   codecs
#   codeop
#   collections
#   colorama
#   colorlog
#   colorsys
#   comm
#   concurrent
#   configparser
#   contextlib
#   contextvars
#   copy
#   copyreg
#   csv
#   ctypes
#   curses
#   cycler
#   cython
#   cython_runtime
#   dataclasses
#   datasets
#   datetime
#   dateutil
#   debugpy
#   decimal
#   decorator
#   defusedxml
#   difflib
#   dill
#   dis
#   dotenv
#   email
#   encodings
#   enum
#   errno
#   executing
#   faulthandler
#   fcntl
#   filecmp
#   fileinput
#   filelock
#   fnmatch
#   fractions
#   frozenlist
#   fsspec
#   functools
#   gc
#   genericpath
#   getopt
#   getpass
#   gettext
#   glob
#   gmpy2
#   google
#   graphviz
#   grp
#   gzip
#   hashlib
#   heapq
#   hmac
#   html
#   http
#   httpx
#   huggingface_hub
#   idna
#   importlib
#   inspect
#   io
#   ipaddress
#   ipykernel
#   ipywidgets
#   itertools
#   jedi
#   jinja2
#   joblib
#   json
#   jupyter_client
#   jupyter_core
#   keyword
#   kiwisolver
#   kret_decorators
#   kret_lgbm
#   kret_lightning
#   kret_matplotlib
#   kret_notebook
#   kret_np_pd
#   kret_optuna
#   kret_polars
#   kret_rosetta
#   kret_sklearn
#   kret_torch_utils
#   kret_tqdm
#   kret_type_hints
#   kret_utils
#   kret_wandb
#   lightgbm
#   lightning
#   lightning_utilities
#   linecache
#   locale
#   logging
#   lzma
#   markupsafe
#   marshal
#   math
#   matplotlib
#   mimetypes
#   mmap
#   modulefinder
#   mpl_toolkits
#   mpmath
#   msgpack
#   multidict
#   multiprocess
#   multiprocessing
#   netrc
#   ntpath
#   numbers
#   numpy
#   opcode
#   operator
#   opt_einsum
#   optree
#   optuna
#   optuna_integration
#   orjson
#   os
#   packaging
#   pandas
#   parso
#   pathlib
#   pathvalidate
#   patsy
#   pdb
#   pickle
#   pickletools
#   pkgutil
#   platform
#   platformdirs
#   plistlib
#   polars
#   posix
#   posixpath
#   pprint
#   profile
#   prompt_toolkit
#   propcache
#   pstats
#   psutil
#   pure_eval
#   pwd
#   pyarrow
#   pycparser
#   pydantic
#   pydantic_core
#   pydev_ipython
#   pydevconsole
#   pydevd
#   pydevd_file_utils
#   pydevd_plugins
#   pydevd_tracing
#   pydoc
#   pydoc_data
#   pydot
#   pyexpat
#   pygments
#   pyparsing
#   pytz
#   queue
#   quopri
#   random
#   re
#   regex
#   reprlib
#   requests
#   resource
#   rich
#   runpy
#   safetensors
#   scipy
#   seaborn
#   secrets
#   select
#   selectors
#   shlex
#   shutil
#   signal
#   site
#   sitecustomize
#   six
#   sklearn
#   socket
#   socketserver
#   socks
#   sqlite3
#   ssl
#   stack_data
#   stat
#   statistics
#   statsmodels
#   string
#   stringprep
#   struct
#   subprocess
#   sympy
#   sys
#   sysconfig
#   tarfile
#   tempfile
#   termios
#   textwrap
#   threading
#   threadpoolctl
#   time
#   timeit
#   token
#   tokenize
#   tokenizers
#   torch
#   torchgen
#   torchmetrics
#   torchvision
#   tornado
#   tqdm
#   traceback
#   traitlets
#   transformers
#   types
#   typing
#   typing_extensions
#   typing_inspection
#   unicodedata
#   unittest
#   urllib
#   urllib3
#   uuid
#   vscode
#   warnings
#   wcwidth
#   weakref
#   xml
#   xmlrpc
#   xxhash
#   yaml
#   yarl
#   zipfile
#   zipimport
#   zlib
#   zmq
#   zoneinfo
#   zstandard

# %% [markdown]
# # Load Data

# %% [markdown]
# # Implementation

# %% [markdown]
# # Sandbox
